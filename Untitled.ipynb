# %%
import pandas as pd

# %%
df = pd.read_csv('12_Chiba Prefecture_20191_20202_e.csv', encoding='SHIFT-JIS')
df.head()
# Out:
#    No                                 Type            Region  \
# 0   1         Pre-owned Condominiums, etc.               NaN
# 1   2         Pre-owned Condominiums, etc.               NaN
# 2   3  Residential Land(Land and Building)  Residential Area
# 3   4         Pre-owned Condominiums, etc.               NaN
# 4   5         Pre-owned Condominiums, etc.               NaN
#
#    City,Town,Ward,Village code        Prefecture City,Town,Ward,Village  \
# 0                        12101  Chiba Prefecture   Chuo Ward,Chiba City
# 1                        12101  Chiba Prefecture   Chuo Ward,Chiba City
# 2                        12101  Chiba Prefecture   Chuo Ward,Chiba City
# 3                        12101  Chiba Prefecture   Chuo Ward,Chiba City
# 4                        12101  Chiba Prefecture   Chuo Ward,Chiba City
#
#       Area Nearest station：Name Nearest station：Distance(minute)  \
# 0  Aobacho                Chiba                     30-60minutes
# ...

# %%
df.shape
# Out:
# (18194, 29)

# %%
df.columns
# Out:
# Index(['No', 'Type', 'Region', 'City,Town,Ward,Village code', 'Prefecture',
#        'City,Town,Ward,Village', 'Area', 'Nearest station：Name',
#        'Nearest station：Distance(minute)', 'Transaction-price(total)',
#        'Layout', 'Area(m^2)', 'Transaction-price(Unit price m^2)',
#        'Land shape', 'Frontage', 'Total floor area(m^2)',
#        'Year of construction', 'Building structure', 'Use', 'Purpose of Use',
#        'Frontage road：Direction', 'Frontage road：Classification',
#        'Frontage road：Breadth(m)', 'City Planning',
#        'Maximus Building Coverage Ratio(%)', 'Maximus Floor-area Ratio(%)',
#        'Transaction period', 'Renovation', 'Transactional factors'],
#       dtype='object')

# %%
df.dtypes
# Out:
# No                                      int64
# Type                                   object
# Region                                 object
# City,Town,Ward,Village code             int64
# Prefecture                             object
# City,Town,Ward,Village                 object
# Area                                   object
# Nearest station：Name                   object
# Nearest station：Distance(minute)       object
# Transaction-price(total)                int64
# Layout                                 object
# Area(m^2)                              object
# Transaction-price(Unit price m^2)     float64
# Land shape                             object
# Frontage                               object
# Total floor area(m^2)                  object
# Year of construction                   object
# Building structure                     object
# Use                                    object
# Purpose of Use                         object
# ...

# %%
df['Transaction period'].value_counts()
# Out:
# 1st quarter 2019    3559
# 2nd quarter 2019    3402
# 1st quarter 2020    3342
# 4th quarter 2019    3316
# 3rd quarter 2019    3135
# 2nd quarter 2020    1440
# Name: Transaction period, dtype: int64

# %%
df.groupby('Transaction period')

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
df.head()
# Out:
#    No                                 Type            Region  \
# 0   1         Pre-owned Condominiums, etc.               NaN
# 1   2         Pre-owned Condominiums, etc.               NaN
# 2   3  Residential Land(Land and Building)  Residential Area
# 3   4         Pre-owned Condominiums, etc.               NaN
# 4   5         Pre-owned Condominiums, etc.               NaN
#
#    City,Town,Ward,Village code        Prefecture City,Town,Ward,Village  \
# 0                        12101  Chiba Prefecture   Chuo Ward,Chiba City
# 1                        12101  Chiba Prefecture   Chuo Ward,Chiba City
# 2                        12101  Chiba Prefecture   Chuo Ward,Chiba City
# 3                        12101  Chiba Prefecture   Chuo Ward,Chiba City
# 4                        12101  Chiba Prefecture   Chuo Ward,Chiba City
#
#       Area Nearest station：Name Nearest station：Distance(minute)  \
# 0  Aobacho                Chiba                     30-60minutes
# ...

# %%
ls
# Out:
# 12_Chiba Prefecture_20191_20202_e.csv
# CONTRIBUTING.md
# LICENSE.md
# README.md
# Untitled.ipynb
# dollar-yen-exchange-rate-historical-chart.csv
# images/
# time-series/

# %%
test = pd.read_csv('DEXJPUS.csv')
test.head()
# Out:
#          DATE   DEXJPUS
# 0  2016-01-15  116.7800
# 1  2016-01-18         .
# 2  2016-01-19  117.6600
# 3  2016-01-20  116.3800
# 4  2016-01-21  117.6100

# %%
test.shape
# Out:
# (1306, 2)

# %%
test.tail()
# Out:
#             DATE DEXJPUS
# 1301  2021-01-11  104.16
# 1302  2021-01-12  104.09
# 1303  2021-01-13  103.91
# 1304  2021-01-14  103.66
# 1305  2021-01-15   103.8

# %%
test.dtypes
# Out:
# DATE       object
# DEXJPUS    object
# dtype: object

# %%
test['DATE'] = pd.to_datetime(test['DATE'])
test.set_index('DATE', inplace=True)
test.head()
# Out:
#              DEXJPUS
# DATE
# 2016-01-15  116.7800
# 2016-01-18         .
# 2016-01-19  117.6600
# 2016-01-20  116.3800
# 2016-01-21  117.6100

# %%
test.dtypes
# Out:
# DEXJPUS    object
# dtype: object

# %%
test.index
# Out:
# DatetimeIndex(['2016-01-15', '2016-01-18', '2016-01-19', '2016-01-20',
#                '2016-01-21', '2016-01-22', '2016-01-25', '2016-01-26',
#                '2016-01-27', '2016-01-28',
#                ...
#                '2021-01-04', '2021-01-05', '2021-01-06', '2021-01-07',
#                '2021-01-08', '2021-01-11', '2021-01-12', '2021-01-13',
#                '2021-01-14', '2021-01-15'],
#               dtype='datetime64[ns]', name='DATE', length=1306, freq=None)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np

# %%
test['DEXJPUS'] = pd.to_numeric(test['DEXJPUS'])
test.head()
# Out:
#             DEXJPUS
# DATE
# 2016-01-15   116.78
# 2016-01-19   117.66
# 2016-01-20   116.38
# 2016-01-21   117.61
# 2016-01-22   118.37

# %%
test['DEXJPUS'].value_counts()
# Out:
# .           57
# 110.54       5
# 108.62       4
# 108.44       4
# 108.53       4
# 108.67       4
# 112.4200     4
# 108.56       4
# 112.3200     4
# 113.6200     4
# 107.06       4
# 105.97       4
# 113.2900     3
# 108.29       3
# 110.34       3
# 110.92       3
# 110.05       3
# 109.1600     3
# 111.38       3
# 109.3400     3
# 109.68       3
# 108.39       3
# 112.0        3
# 106.56       3
# 113.5000     3
# 109.47       3
# 107.26       3
# 107.52       3
# 114.3400     3
# 107.5        3
# 111.6200     3
# 110.7600     3
# 108.83       3
# 112.0600     3
# 108.12       3
# 112.54       3
# 112.7600     3
# 108.66       3
# 109.45       3
# 108.59       3
# 113.9000     3
# 106.83       3
# 110.86       3
# 109.7400     3
# 106.3        3
# 112.7000     3
# 106.52       3
# 110.7400     3
# 107.21       3
# 110.68       3
# 107.69       3
# 106.92       3
# 113.6600     3
# 109.89       3
# 105.3        3
# 109.38       3
# 110.38       3
# 111.48       3
# ...

# %%
drop = test.loc[test['DEXJPUS'] == '.'].index
test.drop(index=drop, inplace=True)

# %%
test['DEXJPUS'].value_counts()
# Out:
# 110.54      5
# 108.62      4
# 107.06      4
# 108.67      4
# 105.97      4
# 113.6200    4
# 108.53      4
# 108.44      4
# 108.56      4
# 112.4200    4
# 112.3200    4
# 106.83      3
# 113.9000    3
# 109.38      3
# 112.0       3
# 111.38      3
# 112.54      3
# 109.45      3
# 110.05      3
# 110.34      3
# 108.83      3
# 114.3400    3
# 112.7600    3
# 108.29      3
# 109.58      3
# 108.66      3
# 108.59      3
# 110.92      3
# 109.3400    3
# 109.7400    3
# 109.1600    3
# 109.47      3
# 113.5000    3
# 109.68      3
# 108.39      3
# 113.2900    3
# 108.12      3
# 111.4800    3
# 112.0600    3
# 106.52      3
# 110.38      3
# 110.7400    3
# 106.92      3
# 112.7000    3
# 107.5       3
# 106.5       3
# 110.68      3
# 105.3       3
# 110.86      3
# 110.7600    3
# 107.21      3
# 109.89      3
# 111.6200    3
# 107.52      3
# 113.6600    3
# 106.56      3
# 107.69      3
# 111.48      3
# 109.16      3
# 112.6800    3
# 106.3       3
# 107.26      3
# ...

# %%
plt.figure(figsize=(12,8))

plt.hist(test, bins='auto')
# Out:
# (array([1.]), array([-0.5,  0.5]), <BarContainer object of 1 artists>)

# %%
test.dtypes
# Out:
# DEXJPUS    float64
# dtype: object

# %%
test.hist(figsize=(12,8), bins='auto')
# Out:
# array([[<AxesSubplot:title={'center':'DEXJPUS'}>]], dtype=object)

# %%
test.index
# Out:
# DatetimeIndex(['2016-01-15', '2016-01-19', '2016-01-20', '2016-01-21',
#                '2016-01-22', '2016-01-25', '2016-01-26', '2016-01-27',
#                '2016-01-28', '2016-01-29',
#                ...
#                '2021-01-04', '2021-01-05', '2021-01-06', '2021-01-07',
#                '2021-01-08', '2021-01-11', '2021-01-12', '2021-01-13',
#                '2021-01-14', '2021-01-15'],
#               dtype='datetime64[ns]', name='DATE', length=1249, freq=None)

# %%
test.dtypes
# Out:
# DEXJPUS    float64
# dtype: object

# %%
test.info
# Out:
# <bound method DataFrame.info of             DEXJPUS
# DATE
# 2016-01-15   116.78
# 2016-01-19   117.66
# 2016-01-20   116.38
# 2016-01-21   117.61
# 2016-01-22   118.37
# 2016-01-25   118.55
# 2016-01-26   118.50
# 2016-01-27   118.90
# 2016-01-28   118.61
# 2016-01-29   121.05
# 2016-02-01   121.06
# 2016-02-02   120.27
# 2016-02-03   117.92
# 2016-02-04   116.75
# 2016-02-05   116.99
# 2016-02-08   115.70
# 2016-02-09   114.80
# 2016-02-10   114.03
# 2016-02-11   111.72
# 2016-02-12   112.96
# 2016-02-16   113.90
# 2016-02-17   114.14
# 2016-02-18   113.62
# 2016-02-19   112.42
# 2016-02-22   113.12
# 2016-02-23   112.17
# 2016-02-24   111.36
# 2016-02-25   112.70
# 2016-02-26   113.78
# 2016-02-29   112.90
# 2016-03-01   113.94
# 2016-03-02   113.81
# 2016-03-03   113.53
# 2016-03-04   113.91
# 2016-03-07   113.60
# 2016-03-08   112.58
# 2016-03-09   113.06
# 2016-03-10   113.10
# 2016-03-11   113.66
# 2016-03-14   113.59
# 2016-03-15   112.88
# 2016-03-16   113.69
# ...

# %%
test.describe()
# Out:
#            DEXJPUS
# count  1249.000000
# mean    109.276653
# std       3.521390
# min     100.070000
# 25%     106.920000
# 50%     109.440000
# 75%     111.740000
# max     121.060000

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1249 entries, 2016-01-15 to 2021-01-15
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   DEXJPUS  1249 non-null   float64
# dtypes: float64(1)
# memory usage: 19.5 KB

# %%
test.plot(figsize=(16,7))
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
test.plot(kind='kde', figsize=(15,10));

# %%
roll_mean = test.rolling(window=8, center=False).mean()
roll_std = test.rolling(window=8, center=False).std()

# %%
fig = plt.figure(figsize=(12,7))
plt.plot(test, color='blue', label='Original')
plt.plot(roll_mean, color='red', label='Rolling Mean')
plt.plot(roll_std, color='black', label = 'Rolling Std')
plt.legend(loc='best')
plt.title('Rolling Mean & Standard Deviation')
plt.show(block=False)

# %%
from statsmodels.tsa.stattools import adfuller
dftest = adfuller(test)

dfoutput = pd.Series(dftest[0:4], index=['Test Statistic', 'p-value', '#Lags Used', 'Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
print(dftest)

print ('Results of Dickey-Fuller test: \n')

print(dfoutput)
# Out:
# (-3.0279736314249526, 0.03236331659998964, 14, 1234, {'1%': -3.435660336370594, '5%': -2.863885022214541, '10%': -2.568018522153254}, 2122.0025644593024)
# Results of Dickey-Fuller test:
#
# Test Statistic                   -3.027974
# p-value                           0.032363
# #Lags Used                       14.000000
# Number of Observations Used    1234.000000
# Critical Value (1%)              -3.435660
# Critical Value (5%)              -2.863885
# Critical Value (10%)             -2.568019
# dtype: float64

# %%
test.corr()
# Out:
#          DEXJPUS
# DEXJPUS      1.0

# %%
test.diff(periods=1)
# Out:
#             DEXJPUS
# DATE
# 2016-01-15      NaN
# 2016-01-19     0.88
# 2016-01-20    -1.28
# 2016-01-21     1.23
# 2016-01-22     0.76
# 2016-01-25     0.18
# 2016-01-26    -0.05
# 2016-01-27     0.40
# 2016-01-28    -0.29
# 2016-01-29     2.44
# 2016-02-01     0.01
# 2016-02-02    -0.79
# 2016-02-03    -2.35
# 2016-02-04    -1.17
# 2016-02-05     0.24
# 2016-02-08    -1.29
# 2016-02-09    -0.90
# 2016-02-10    -0.77
# 2016-02-11    -2.31
# 2016-02-12     1.24
# 2016-02-16     0.94
# 2016-02-17     0.24
# 2016-02-18    -0.52
# 2016-02-19    -1.20
# 2016-02-22     0.70
# 2016-02-23    -0.95
# 2016-02-24    -0.81
# 2016-02-25     1.34
# 2016-02-26     1.08
# 2016-02-29    -0.88
# 2016-03-01     1.04
# 2016-03-02    -0.13
# 2016-03-03    -0.28
# 2016-03-04     0.38
# 2016-03-07    -0.31
# 2016-03-08    -1.02
# 2016-03-09     0.48
# 2016-03-10     0.04
# 2016-03-11     0.56
# 2016-03-14    -0.07
# 2016-03-15    -0.71
# 2016-03-16     0.81
# 2016-03-17    -2.39
# 2016-03-18     0.08
# ...

# %%
log_test = np.log(test)
log_test.plot(figsize=(16,8));

# %%
sq_test = test**2
sq_test.plot(figsize=(16,8));
